# %%
from bs4 import BeautifulSoup as bs
import requests
import time
import pandas as pd

# %%
base_url = 'https://fbref.com/'
scores_url = 'https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures'

scores = requests.get(scores_url)
soup = bs(scores.text)
next_season = soup.find("a", class_="next")
next_season_link = base_url + next_season["href"]

# %%
table = pd.read_html(next_season_link)

# %%
next_season_link_soup = bs(requests.get(next_season_link).text)
next_season_title = next_season_link_soup.find_all('div', class_='comps')

# %%
next_season_title = next_season_link_soup.find('div', class_='comps')
next_season_title1 = next_season_title.find('h1').text.strip('\t\r\n')

# %%
nxt_season = next_season_title1.split("-")[1].split(" ")[0]
# browser.quit()

# %%
upcoming_matches = table[0]
upcoming_matches = upcoming_matches[['Wk', 'Day', 'Date', 'Time', 'Home', 'Away', 'Venue']]

# %%
upcoming_matches= upcoming_matches.dropna()

# %%
upcoming_matches
# Out:
#        Wk  Day        Date   Time            Home             Away  \
# 0     1.0  Fri  2022-08-05  20:00  Crystal Palace          Arsenal
# 1     1.0  Sat  2022-08-06  12:30          Fulham        Liverpool
# 2     1.0  Sat  2022-08-06  15:00       Tottenham      Southampton
# 3     1.0  Sat  2022-08-06  15:00   Newcastle Utd  Nott'ham Forest
# 4     1.0  Sat  2022-08-06  15:00    Leeds United           Wolves
# ..    ...  ...         ...    ...             ...              ...
# 412  38.0  Sun  2023-05-28  15:00         Everton      Bournemouth
# 413  38.0  Sun  2023-05-28  15:00  Leicester City         West Ham
# 414  38.0  Sun  2023-05-28  15:00     Aston Villa         Brighton
# 415  38.0  Sun  2023-05-28  15:00    Leeds United        Tottenham
# 416  38.0  Sun  2023-05-28  15:00       Brentford  Manchester City
#
#                            Venue season mod1 mod2 mod3 mod4
# 0                  Selhurst Park   2023
# 1                 Craven Cottage   2023
# 2      Tottenham Hotspur Stadium   2023
# 3                St. James' Park   2023
# 4                    Elland Road   2023
# ..                           ...    ...  ...  ...  ...  ...
# 412                Goodison Park   2023
# 413           King Power Stadium   2023
# 414                   Villa Park   2023
# 415                  Elland Road   2023
# 416  Brentford Community Stadium   2023
#
# [380 rows x 12 columns]

# %%
upcoming_matches['season'] = nxt_season
upcoming_matches['mod1'] = ''
upcoming_matches['mod2'] = ''
upcoming_matches['mod3'] = ''
upcoming_matches['mod4'] = ''
upcoming_matches['daynum'] =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2788/520114458.py in <module>
#       4 upcoming_matches['mod3'] = ''
#       5 upcoming_matches['mod4'] = ''
# ----> 6 upcoming_matches['daynum'] = time.strptime(upcoming_matches['Day'], "%A").tm_wday
#
# ~\anaconda3\lib\_strptime.py in _strptime_time(data_string, format)
#     560     """Return a time struct based on the input string and the
#     561     format string."""
# --> 562     tt = _strptime(data_string, format)[0]
#     563     return time.struct_time(tt[:time._STRUCT_TM_ITEMS])
#     564
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     315         if not isinstance(arg, str):
#     316             msg = "strptime() argument {} must be str, not {}"
# --> 317             raise TypeError(msg.format(index, type(arg)))
#     318
#     319     global _TimeRE_cache, _regex_cache
#
# TypeError: strptime() argument 0 must be str, not <class 'pandas.core.series.Series'>

# %%
time.strptime('friday', "%A").tm_wday
# Out:
# 4

# %%
for daynum in upcoming_matches['Day']:
    print(time.strptime(daynum, "%A").tm_wday)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2788/2090363511.py in <module>
#       1 for daynum in upcoming_matches['Day']:
# ----> 2     print(time.strptime(daynum, "%A").tm_wday)
#
# ~\anaconda3\lib\_strptime.py in _strptime_time(data_string, format)
#     560     """Return a time struct based on the input string and the
#     561     format string."""
# --> 562     tt = _strptime(data_string, format)[0]
#     563     return time.struct_time(tt[:time._STRUCT_TM_ITEMS])
#     564
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data 'Fri' does not match format '%A'

# %%
upcoming_matches_df = upcoming_matches.iloc[0:]

# %%
upcoming_matches_df = upcoming_matches_df.reset_index(drop=True)

# %%
upcoming_matches_df
# Out:
#        Wk  Day        Date   Time            Home             Away  \
# 0     1.0  Fri  2022-08-05  20:00  Crystal Palace          Arsenal
# 1     1.0  Sat  2022-08-06  12:30          Fulham        Liverpool
# 2     1.0  Sat  2022-08-06  15:00       Tottenham      Southampton
# 3     1.0  Sat  2022-08-06  15:00   Newcastle Utd  Nott'ham Forest
# 4     1.0  Sat  2022-08-06  15:00    Leeds United           Wolves
# ..    ...  ...         ...    ...             ...              ...
# 375  38.0  Sun  2023-05-28  15:00         Everton      Bournemouth
# 376  38.0  Sun  2023-05-28  15:00  Leicester City         West Ham
# 377  38.0  Sun  2023-05-28  15:00     Aston Villa         Brighton
# 378  38.0  Sun  2023-05-28  15:00    Leeds United        Tottenham
# 379  38.0  Sun  2023-05-28  15:00       Brentford  Manchester City
#
#                            Venue season mod1 mod2 mod3 mod4
# 0                  Selhurst Park   2023
# 1                 Craven Cottage   2023
# 2      Tottenham Hotspur Stadium   2023
# 3                St. James' Park   2023
# 4                    Elland Road   2023
# ..                           ...    ...  ...  ...  ...  ...
# 375                Goodison Park   2023
# 376           King Power Stadium   2023
# 377                   Villa Park   2023
# 378                  Elland Road   2023
# 379  Brentford Community Stadium   2023
#
# [380 rows x 12 columns]
